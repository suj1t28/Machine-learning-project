# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\ADMIN\\Placement_Data.csv')

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
pwd
# Out:
# 'C:\\Users\\ADMIN'

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
#Get all features name

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
#find no of record & column

# %%
df.shape
# Out:
# (215, 15)

# %%
#use the info method to find the no of non null entries and data type of each feature

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
##What is the average Secondary Education percentage - 10th Grade*

# %%
df['ssc_p'].mean()
# Out:
# 67.30339534883721

# %%
##How many toppers where there in 10th Grade?**

# %%
df['ssc_p'].value_counts()
# Out:
# 62.00    11
# 63.00    10
# 67.00     9
# 52.00     9
# 73.00     9
#          ..
# 69.70     1
# 80.92     1
# 83.00     1
# 86.50     1
# 80.60     1
# Name: ssc_p, Length: 103, dtype: int64

# %%
df[df.ssc_p==df.ssc_p.max()]['ssc_p'].value_counts()
# Out:
# 89.4    1
# Name: ssc_p, dtype: int64

# %%
##Is the student who got highest Secondary Eduaction percentage, placed or not?**

# %%
df[df.ssc_p==df.ssc_p.max()]['status']
# Out:
# 145    Placed
# Name: status, dtype: object

# %%
##How many students are placed or unplaced?**

# %%
df['status'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
#is the student who got highest secondary education percentage , placed or not ?

# %%
df[df.hsc_p==df.hsc_p.max()]['status']
# Out:
# 24    Placed
# Name: status, dtype: object

# %%
##What is the most common degree of the placed students?*

# %%
df[df.status=='Placed']['degree_t'].value_counts().head(1)
# Out:
# Comm&Mgmt    102
# Name: degree_t, dtype: int64

# %%
##How many unique degrees are there in the dataset?**

# %%
df['degree_t'].nunique()
# Out:
# 3

# %%
##Is there a correlation between 10th and 12th percentage**

# %%
df[['ssc_p','hsc_p']].corr()
# Out:
#           ssc_p     hsc_p
# ssc_p  1.000000  0.511472
# hsc_p  0.511472  1.000000

# %%
#find corelation matrix

# %%
df.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %% [markdown]
# Data preprocessing
# #Remove unnecessary column i.e sr no
# ##Identify the column which can be removed?(only 1)**

# %%
df.drop(columns=['sl_no'],inplace=True)

# %%
##Check number of null values in each column**

# %%
df.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#Fill the missing value with appropriate values and check the number of null values in each column

# %%
df.fillna(0,inplace=True)

# %%
#Data visualization
#Import matplotlib and seaborn

# %%
##Draw the scatter plot between 10th and 12th class percentage with leble & title

# %%
plt.scatter(df['ssc_p'],df['hsc_p'])
plt.xlabel('10th percentage')
plt.ylabel('12th Percentage')
plt.title('Scatter plot between 10th and 12th percentage')
# Out:
# Text(0.5, 1.0, 'Scatter plot between 10th and 12th percentage')

# %%
##Draw the scatter plot between 10th and 12th class percentage of students grouped based on placement data*

# %%
sns.scatterplot(x=df['ssc_p'],y=df['hsc_p'],hue=df['status'])
# Out:
# <AxesSubplot: xlabel='ssc_p', ylabel='hsc_p'>

# %%
##*Draw the pairplots between all continuous columns**

# %%
sns.pairplot(df.drop(['sl_no'],axis=1),hue='status')

# %%
#Draw a boxplot of 10 th percentage of students

# %%
sns.boxplot(y='ssc_p',data=df)
# Out:
# <AxesSubplot: ylabel='ssc_p'>

# %%
#Draw a boxplot of 12 th percentage of students

# %%
sns.boxplot(y='hsc_p',data=df)
# Out:
# <AxesSubplot: ylabel='hsc_p'>

# %%
#Draw a boxplot for 12th percentage of the students for placed and unplaced students**

# %%
sns.boxplot(y='hsc_p',data=df,x='status')
# Out:
# <AxesSubplot: xlabel='status', ylabel='hsc_p'>

# %% [markdown]
# **Draw lineplot for 10th, 12th, degree and MBA percentage**

# %%
plt.plot(df[['hsc_p','ssc_p','degree_p','mba_p']])

# %%
plt.plot(df['hsc_p'],label='10th Marks')
plt.plot(df['ssc_p'],label='12th Marks')
plt.plot(df['mba_p'],label='MBA Marks')
plt.legend()
plt.show()

# %%
**Find correlation between continous columns*

# %%
df.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.063764
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.035330
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.076819
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.019272
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.178307
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
**Draw heatmap of correlation**

# %%
plt.figure(figsize=(15,8), dpi=80)
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot: >

# %%
**Draw histogram for salary of students**

# %%
plt.hist(df['salary'])
# Out:
# (array([84., 39., 17.,  2.,  3.,  0.,  2.,  0.,  0.,  1.]),
#  array([200000., 274000., 348000., 422000., 496000., 570000., 644000.,
#         718000., 792000., 866000., 940000.]),
#  <BarContainer object of 10 artists>)

# %%
**Draw the distribution of 10th Grade percentage**

# %%
sns.kdeplot(df['ssc_p'])
# Out:
# <AxesSubplot: xlabel='ssc_p', ylabel='Density'>

# %%
sns.boxplot(df['degree_p'])
# Out:
# <AxesSubplot: >

# %%
#Outliers

# %%
per25=df['degree_p'].quantile(0.25)

# %%
per75=df['degree_p'].quantile(0.75)

# %%
iqr=per75-per25

# %%
iqr
# Out:
# 11.0

# %%
upperlimit=per75+(1.5*iqr)
lowerlimit=per25-(1.5*iqr)

# %%
upperlimit
# Out:
# 88.5

# %%
lowerlimit
# Out:
# 44.5

# %%
df=df[(df['degree_p']>lowerlimit) & (df['degree_p']<upperlimit)]

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
sns.boxplot(y='degree_p',data=df)
# Out:
# <AxesSubplot: ylabel='degree_p'>

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
col=['ssc_p','hsc_p','etest_p','mba_p','salary']
for c in col:
    per25=df[c].quantile(0.25)
    per75=df[c].quantile(0.75)
    iqr=per75-per25
    upperlimit=per75+(1.5*iqr)
    lowerlimit=per25-(1.5*iqr)
    A=df[(df[c]>lowerlimit) & (df[c]<upperlimit)]
    plt.figure()
    sns.boxplot(y=c,data=A)

# %%
#LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
col=['gender','ssc_b','hsc_b','hsc_s','degree_t','workex','specialisation','status']
for c in col:
    df[c]=le.fit_transform(df[c])

# %%
df
# Out:
#      gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0         1  67.00      1  91.00      1      1     58.00         2       0
# 1         1  79.33      0  78.33      1      2     77.48         2       1
# 2         1  65.00      0  68.00      0      0     64.00         0       0
# 3         1  56.00      0  52.00      0      2     52.00         2       0
# 4         1  85.80      0  73.60      0      1     73.30         0       0
# ..      ...    ...    ...    ...    ...    ...       ...       ...     ...
# 210       1  80.60      1  82.00      1      1     77.60         0       0
# 211       1  58.00      1  60.00      1      2     72.00         2       0
# 212       1  67.00      1  67.00      1      1     73.00         0       1
# 213       0  74.00      1  66.00      1      1     58.00         0       0
# 214       1  62.00      0  58.00      1      2     53.00         0       0
#
#      etest_p  specialisation  mba_p  status    salary
# ...

# %%
Extract independent and dependent variables

# %%
x=df.iloc[:,0:-1]

# %%
y=df.iloc[:,-1]

# %%
x=df.iloc[:,0:-1].values

# %%
x
# Out:
# array([[ 1.  , 67.  ,  1.  , ...,  1.  , 58.8 ,  1.  ],
#        [ 1.  , 79.33,  0.  , ...,  0.  , 66.28,  1.  ],
#        [ 1.  , 65.  ,  0.  , ...,  0.  , 57.8 ,  1.  ],
#        ...,
#        [ 1.  , 67.  ,  1.  , ...,  0.  , 69.72,  1.  ],
#        [ 0.  , 74.  ,  1.  , ...,  1.  , 60.23,  1.  ],
#        [ 1.  , 62.  ,  0.  , ...,  1.  , 60.22,  0.  ]])

# %%
y=df.iloc[:,-1].values

# %%
y
# Out:
# array([270000., 200000., 250000.,      0., 425000.,      0.,      0.,
#        252000., 231000.,      0., 260000., 250000.,      0., 218000.,
#             0., 200000., 300000.,      0.,      0., 236000., 265000.,
#        393000., 360000., 300000., 360000.,      0., 240000., 265000.,
#        350000.,      0., 250000.,      0., 278000., 260000.,      0.,
#        300000.,      0., 320000., 240000., 411000., 287000.,      0.,
#             0., 300000., 200000.,      0.,      0., 204000., 250000.,
#             0., 200000.,      0.,      0., 450000., 216000., 220000.,
#        240000., 360000., 268000., 265000., 260000., 300000., 240000.,
#             0., 240000.,      0., 275000., 275000.,      0., 275000.,
#        360000., 240000., 240000., 218000., 336000.,      0., 230000.,
#        500000., 270000.,      0., 240000., 300000.,      0., 300000.,
#        300000., 400000., 220000.,      0., 210000., 210000., 300000.,
# ...

# %%
#Split dataset into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[ 1.  , 52.  ,  0.  , ...,  1.  , 55.41,  0.  ],
#        [ 1.  , 70.  ,  0.  , ...,  0.  , 62.  ,  1.  ],
#        [ 1.  , 73.  ,  0.  , ...,  0.  , 62.16,  1.  ],
#        ...,
#        [ 0.  , 60.23,  0.  , ...,  0.  , 59.47,  1.  ],
#        [ 0.  , 77.8 ,  0.  , ...,  1.  , 72.14,  0.  ],
#        [ 0.  , 77.  ,  1.  , ...,  0.  , 61.31,  1.  ]])

# %%
y_train
# Out:
# array([     0., 300000., 420000., 225000., 400000., 220000., 285000.,
#        240000., 240000., 360000.,      0.,      0.,      0., 236000.,
#        275000.,      0., 260000.,      0.,      0.,      0., 240000.,
#             0.,      0.,      0.,      0.,      0.,      0.,      0.,
#             0., 300000., 350000.,      0.,      0., 380000., 233000.,
#             0., 250000.,      0., 230000.,      0., 300000., 270000.,
#        250000., 240000., 300000., 280000., 350000., 250000., 500000.,
#             0., 204000., 216000., 300000., 400000.,      0.,      0.,
#        236000., 300000., 360000.,      0., 940000., 260000., 250000.,
#        216000.,      0.,      0., 265000., 250000.,      0., 300000.,
#        425000., 278000.,      0.,      0., 300000., 250000., 250000.,
#        260000., 240000., 210000., 255000., 650000., 270000., 300000.,
#        500000., 360000.,      0., 240000., 200000., 265000., 287000.,
# ...

# %%
#Use standardization and perform Linear Regression

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.72258141, -1.39473047, -0.96570403, ...,  1.13724814,
#         -1.15170167, -1.4585173 ],
#        [ 0.72258141,  0.26292848, -0.96570403, ..., -0.87931557,
#         -0.03847026,  0.68562779],
#        [ 0.72258141,  0.53920498, -0.96570403, ..., -0.87931557,
#         -0.01144188,  0.68562779],
#        ...,
#        [-1.38392711, -0.63681196, -0.96570403, ..., -0.87931557,
#         -0.46585653,  0.68562779],
#        [-1.38392711,  0.98124736, -0.96570403, ...,  1.13724814,
#          1.67445333, -1.4585173 ],
#        [-1.38392711,  0.90757363,  1.03551396, ..., -0.87931557,
#         -0.15503015,  0.68562779]])

# %%
x_test=sc.transform(x_test)

# %%
#Perform Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 197209.30232558135

# %%
reg.coef_
# Out:
# array([  6230.0540783 , -15220.27953545,   4699.56299871,   7660.42918281,
#         -2392.8423154 ,   1174.75212105,  -5262.63813876,   9056.27953979,
#          3526.97767367,  15187.11078185,  -6548.04635038,  14209.58045627,
#        136642.49666265])

# %%
y_predict=reg.predict(x_test)

# %%
y_predict
# Out:
# array([283445.89722654, 300913.7853785 , 334347.83458   , 243144.39322595,
#        296955.68820456,  11200.39279789, -21539.51068457, 306349.94461525,
#        301038.82953116, 256384.76125544,   8856.87237266, 231978.88480117,
#        -10591.67018879, -28737.41814731, 275887.8183028 ,  28386.20343935,
#        288704.58839648, -22400.05909179, 362270.36304842, 253598.84322459,
#        275629.45341391, 264723.24679531,   5001.01443568,  36419.93708782,
#        248243.79939199, 270893.91381214,  40945.15736471, 290611.01458607,
#        -30526.10400245, 294642.81426191, 311300.57902962, 260188.07662358,
#        258168.93854424, 290950.47895814, 289627.33471988, 328984.66538026,
#        -20003.17079909, 234399.28612582, 343493.53423193, 265386.71058835,
#        267927.36135651, 270232.85341501, 324786.51877525])

# %%
y_test
# Out:
# array([300000., 295000., 250000., 220000., 200000.,      0.,      0.,
#        218000., 210000., 220000.,      0., 250000.,      0.,      0.,
#        275000.,      0., 290000.,      0., 340000., 275000., 252000.,
#        260000.,      0.,      0., 360000., 400000.,      0., 300000.,
#             0., 690000., 300000., 220000., 250000., 264000., 250000.,
#        400000.,      0., 200000., 276000., 220000., 300000., 276000.,
#        240000.])

# %%
#Evaluate the model using MSE,RMSE and R Sqared

# %%
from sklearn import metrics

# %%
MSE=metrics.mean_squared_error(y_test,y_predict)

# %%
RMSE=np.sqrt(MSE)

# %%
RMSE
# Out:
# 76957.30953581621

# %%
MSE
# Out:
# 5922427490.991428

# %%
R2=metrics.r2_score(y_test,y_predict)

# %%
R2
# Out:
# 0.7314549093565583
